# %% [markdown]
# using Revise

# %%
using TopOpt, LinearAlgebra, StatsFuns
using StatsFuns: logsumexp

E = 1.0 # Young’s modulus
v = 0.3 # Poisson’s ratio
f = 1.0 # downward force
rmin = 3.0
# Out:
# 3.0

# %% [markdown]
# ### Define the problem

# %%
problem = PointLoadCantilever(Val{:Linear}, (160, 40), (1.0, 1.0), E, v, f)
# Out:
# TopOpt point load cantilever beam problem

# %% [markdown]
# ### Parameter settings

# %%
V = 0.5 # volume fraction
xmin = 0.0001 # minimum density
steps = 40 # maximum number of penalty steps, delta_p0 = 0.1
# Out:
# 40

# %% [markdown]
# ### Continuation SIMP

# %%
x0 = fill(0.5, 160 * 40) # initial design
N = length(x0)
penalty = TopOpt.PowerPenalty(1.0)
solver = FEASolver(DirectSolver, problem; xmin=xmin, penalty=penalty)
stress = TopOpt.von_mises_stress_function(solver)
filter = DensityFilter(solver; rmin=rmin)
volfrac = TopOpt.Volume(solver)

obj = x -> volfrac(filter(PseudoDensities(x))) - V
thr = 150 # stress threshold
constr = x -> begin
    s = stress(filter(PseudoDensities(x)))
    return (s .- thr) / length(s)
end
alg = PercivalAlg()
options = PercivalOptions()
model = Model(obj)
addvar!(model, zeros(N), ones(N))
add_ineq_constraint!(model, constr)

x = copy(x0)
for p in [1.0, 2.0, 3.0]
    TopOpt.setpenalty!(solver, p)
    global r = optimize(model, alg, x; options)
    global x = r.minimizer
end

maximum(stress(filter(PseudoDensities(x0))))
maximum(stress(filter(PseudoDensities(x))))
# Out:
# [ Info:   iter        fx    normgp    normcx         μ     normy    sumc     inner_status        iter_type
# [ Info:      0  -2.8e-16   8.0e+01   1.9e+00   1.0e+01   8.0e+01       5
# [ Info:      1   3.6e-15   8.0e+01   1.9e+00   1.0e+02   8.0e+01       9      first_order         update_μ
# [ Info:      2  -6.6e-06   8.0e+01   8.0e-01   1.0e+03   8.0e+01      22      first_order         update_μ
# [ Info:      3  -4.9e-01   3.8e-01   8.0e-02   1.0e+03   3.2e-01     561         max_eval         update_y
# [ Info:      4  -4.9e-01   3.8e-01   8.0e-02   1.0e+04   3.2e-01     565         max_eval         update_μ
# [ Info:      5  -4.9e-01   7.9e+01   8.0e-02   1.0e+04   8.0e+02     569         max_eval         update_y
# [ Info:      6  -4.9e-01   7.9e+01   8.0e-02   1.0e+05   8.0e+02     573         max_eval         update_μ
# [ Info:      7  -4.9e-01   7.9e+01   8.0e-02   1.0e+05   8.8e+03     577         max_eval         update_y
# [ Info:      8  -4.9e-01   7.9e+01   8.0e-02   1.0e+06   8.8e+03     581         max_eval         update_μ
# [ Info:      9  -4.9e-01   7.9e+01   8.0e-02   1.0e+06   8.9e+04     585         max_eval         update_y
# [ Info:     10  -4.9e-01   7.9e+01   8.0e-02   1.0e+07   8.9e+04     589         max_eval         update_μ
# [ Info:     11  -4.9e-01   7.9e+01   8.0e-02   1.0e+07   8.9e+05     593         max_eval         update_y
# [ Info:     12  -4.9e-01   7.9e+01   8.0e-02   1.0e+08   8.9e+05     597         max_eval         update_μ
# [ Info:     13  -4.9e-01   7.9e+01   8.0e-02   1.0e+08   8.9e+06     601         max_eval         update_y
# [ Info:     14  -4.9e-01   7.9e+01   8.0e-02   1.0e+09   8.9e+06     605         max_eval         update_μ
# [ Info:     15  -4.9e-01   7.9e+01   8.0e-02   1.0e+09   8.9e+07     609         max_eval         update_y
# [ Info:     16  -4.9e-01   7.9e+01   8.0e-02   1.0e+10   8.9e+07     613         max_eval         update_μ
# [ Info:     17  -4.9e-01   7.9e+01   8.0e-02   1.0e+10   8.9e+08     617         max_eval         update_y
# [ Info:     18  -4.9e-01   7.9e+01   8.0e-02   1.0e+11   8.9e+08     621         max_eval         update_μ
# [ Info:     19  -4.9e-01   7.9e+01   8.0e-02   1.0e+12   8.9e+08     625         max_eval         update_μ
# [ Info:     20  -4.9e-01   7.9e+01   8.0e-02   1.0e+13   8.9e+08     629         max_eval         update_μ
# [ Info:     21  -4.9e-01   7.9e+01   8.0e-02   1.0e+14   8.9e+08     633         max_eval         update_μ
# [ Info:     22  -4.9e-01   7.9e+01   8.0e-02   1.0e+15   8.9e+08     637         max_eval         update_μ
# [ Info:     23  -4.9e-01   7.9e+01   8.0e-02   1.0e+16   8.9e+08     641         max_eval         update_μ
# [ Info:     24  -4.9e-01   7.9e+01   8.0e-02   1.0e+17   8.9e+08     645         max_eval         update_μ
# [ Info:   iter        fx    normgp    normcx         μ     normy    sumc     inner_status        iter_type
# [ Info:      0  -4.9e-01   8.0e+01   6.0e+00   1.0e+01   8.0e+01       5
# [ Info:      1  -4.9e-01   8.0e+01   6.0e+00   1.0e+02   8.0e+01       9      first_order         update_μ
# [ Info:      2  -4.0e-01   8.0e+01   8.0e-01   1.0e+03   8.0e+01      37      first_order         update_μ
# [ Info:      3  -4.0e-01   2.3e-02   8.0e-02   1.0e+03   1.8e-02      71      first_order         update_y
# [ Info:      4  -4.2e-01   2.8e-01   5.7e-04   1.0e+03   5.7e-01     592         max_eval         update_y
# [ Info:      5  -4.2e-01   2.8e-01   5.7e-04   1.0e+04   5.7e-01     596         max_eval         update_μ
# [ Info:      6  -4.2e-01   2.9e+00   5.7e-04   1.0e+04   6.3e+00     600         max_eval         update_y
# [ Info:      7  -4.2e-01   2.9e+00   5.7e-04   1.0e+05   6.3e+00     604         max_eval         update_μ
# [ Info:      8  -4.2e-01   2.8e+01   5.7e-04   1.0e+05   6.3e+01     608         max_eval         update_y
# [ Info:      9  -4.2e-01   2.8e+01   5.7e-04   1.0e+06   6.3e+01     612         max_eval         update_μ
# [ Info:     10  -4.2e-01   2.7e+02   5.7e-04   1.0e+06   6.3e+02     616         max_eval         update_y
# [ Info:     11  -4.2e-01   2.7e+02   5.7e-04   1.0e+07   6.3e+02     620         max_eval         update_μ
# [ Info:     12  -4.2e-01   2.7e+03   5.7e-04   1.0e+07   6.3e+03     624         max_eval         update_y
# [ Info:     13  -4.2e-01   2.7e+03   5.7e-04   1.0e+08   6.3e+03     628         max_eval         update_μ
# [ Info:     14  -4.2e-01   2.7e+04   5.7e-04   1.0e+08   6.3e+04     632         max_eval         update_y
# [ Info:     15  -4.2e-01   2.7e+04   5.7e-04   1.0e+09   6.3e+04     636         max_eval         update_μ
# [ Info:     16  -4.2e-01   2.7e+05   5.7e-04   1.0e+09   6.3e+05     640         max_eval         update_y
# [ Info:     17  -4.2e-01   2.7e+05   5.7e-04   1.0e+10   6.3e+05     644         max_eval         update_μ
# [ Info:     18  -4.2e-01   2.7e+06   5.7e-04   1.0e+10   6.3e+06     648         max_eval         update_y
# [ Info:     19  -4.2e-01   2.7e+06   5.7e-04   1.0e+11   6.3e+06     652         max_eval         update_μ
# [ Info:     20  -4.2e-01   2.7e+07   5.7e-04   1.0e+11   6.3e+07     656         max_eval         update_y
# [ Info:     21  -4.2e-01   2.7e+07   5.7e-04   1.0e+12   6.3e+07     660         max_eval         update_μ
# [ Info:     22  -4.2e-01   2.7e+08   5.7e-04   1.0e+12   6.3e+08     664         max_eval         update_y
# [ Info:     23  -4.2e-01   2.7e+08   5.7e-04   1.0e+13   6.3e+08     668         max_eval         update_μ
# [ Info:     24  -4.2e-01   2.7e+09   5.7e-04   1.0e+13   6.3e+09     672         max_eval         update_y
# [ Info:     25  -4.2e-01   2.7e+09   5.7e-04   1.0e+14   6.3e+09     676         max_eval         update_μ
# [ Info:     26  -4.2e-01   2.7e+10   5.7e-04   1.0e+14   6.3e+10     680         max_eval         update_y
# [ Info:     27  -4.2e-01   2.7e+10   5.7e-04   1.0e+15   6.3e+10     684         max_eval         update_μ
# [ Info:     28  -4.2e-01   2.7e+11   5.7e-04   1.0e+15   6.3e+11     688         max_eval         update_y
# [ Info:     29  -4.2e-01   2.7e+11   5.7e-04   1.0e+16   6.3e+11     692         max_eval         update_μ
# [ Info:     30  -4.2e-01   2.7e+12   5.7e-04   1.0e+16   6.3e+12     696         max_eval         update_y
# [ Info:     31  -4.2e-01   2.7e+12   5.7e-04   1.0e+17   6.3e+12     700         max_eval         update_μ
# [ Info:   iter        fx    normgp    normcx         μ     normy    sumc     inner_status        iter_type
# [ Info:      0  -4.2e-01   8.0e+01   3.5e+00   1.0e+01   8.0e+01       5
# [ Info:      1  -4.2e-01   8.0e+01   3.5e+00   1.0e+02   8.0e+01       9      first_order         update_μ
# [ Info:      2  -3.4e-01   8.0e+01   8.0e-01   1.0e+03   8.0e+01      28      first_order         update_μ
# [ Info:      3  -3.4e-01   5.0e-02   8.0e-02   1.0e+03   1.1e-01      92      first_order         update_y
# [ Info:      4  -3.5e-01   9.5e-02   5.5e-04   1.0e+03   5.4e-01     600         max_eval         update_y
# [ Info:      5  -3.5e-01   9.5e-02   5.5e-04   1.0e+04   5.4e-01     604         max_eval         update_μ
# [ Info:      6  -3.5e-01   1.4e+00   5.5e-04   1.0e+04   6.1e+00     608         max_eval         update_y
# [ Info:      7  -3.5e-01   1.4e+00   5.5e-04   1.0e+05   6.1e+00     612         max_eval         update_μ
# [ Info:      8  -3.5e-01   1.5e+01   5.5e-04   1.0e+05   6.1e+01     616         max_eval         update_y
# [ Info:      9  -3.5e-01   1.5e+01   5.5e-04   1.0e+06   6.1e+01     620         max_eval         update_μ
# [ Info:     10  -3.5e-01   1.4e+02   5.5e-04   1.0e+06   6.2e+02     624         max_eval         update_y
# [ Info:     11  -3.5e-01   1.4e+02   5.5e-04   1.0e+07   6.2e+02     628         max_eval         update_μ
# [ Info:     12  -3.5e-01   1.4e+03   5.5e-04   1.0e+07   6.2e+03     632         max_eval         update_y
# [ Info:     13  -3.5e-01   1.4e+03   5.5e-04   1.0e+08   6.2e+03     636         max_eval         update_μ
# [ Info:     14  -3.5e-01   1.4e+04   5.5e-04   1.0e+08   6.2e+04     640         max_eval         update_y
# [ Info:     15  -3.5e-01   1.4e+04   5.5e-04   1.0e+09   6.2e+04     644         max_eval         update_μ
# [ Info:     16  -3.5e-01   1.4e+05   5.5e-04   1.0e+09   6.2e+05     648         max_eval         update_y
# [ Info:     17  -3.5e-01   1.4e+05   5.5e-04   1.0e+10   6.2e+05     652         max_eval         update_μ
# [ Info:     18  -3.5e-01   1.4e+06   5.5e-04   1.0e+10   6.2e+06     656         max_eval         update_y
# [ Info:     19  -3.5e-01   1.4e+06   5.5e-04   1.0e+11   6.2e+06     660         max_eval         update_μ
# [ Info:     20  -3.5e-01   1.4e+07   5.5e-04   1.0e+11   6.2e+07     664         max_eval         update_y
# [ Info:     21  -3.5e-01   1.4e+07   5.5e-04   1.0e+12   6.2e+07     668         max_eval         update_μ
# [ Info:     22  -3.5e-01   1.4e+08   5.5e-04   1.0e+12   6.2e+08     672         max_eval         update_y
# [ Info:     23  -3.5e-01   1.4e+08   5.5e-04   1.0e+13   6.2e+08     676         max_eval         update_μ
# [ Info:     24  -3.5e-01   1.4e+09   5.5e-04   1.0e+13   6.2e+09     680         max_eval         update_y
# [ Info:     25  -3.5e-01   1.4e+09   5.5e-04   1.0e+14   6.2e+09     684         max_eval         update_μ
# [ Info:     26  -3.5e-01   1.4e+10   5.5e-04   1.0e+14   6.2e+10     688         max_eval         update_y
# [ Info:     27  -3.5e-01   1.4e+10   5.5e-04   1.0e+15   6.2e+10     692         max_eval         update_μ
# [ Info:     28  -3.5e-01   1.4e+11   5.5e-04   1.0e+15   6.2e+11     696         max_eval         update_y
# [ Info:     29  -3.5e-01   1.4e+11   5.5e-04   1.0e+16   6.2e+11     700         max_eval         update_μ
# [ Info:     30  -3.5e-01   1.4e+12   5.5e-04   1.0e+16   6.2e+12     704         max_eval         update_y
# [ Info:     31  -3.5e-01   1.4e+12   5.5e-04   1.0e+17   6.2e+12     708         max_eval         update_μ
# 152.62085898883842

# %% [markdown]
# ### (Optional) Visualize the result using Makie.jl
# Need to run `using Pkg; Pkg.add("Makie")` first and either `Pkg.add("CairoMakie")` or `Pkg.add("GLMakie")`

# %%
using Makie
using CairoMakie

# %% [markdown]
# alternatively, `using GLMakie`

# %%
fig = visualize(
    problem;
    topology=r.minimizer,
    default_exagg_scale=0.07,
    scale_range=10.0,
    vector_arrowsize=0.5,
)
Makie.display(fig)
# Out:
# Figure()
# CairoMakie.Screen{IMAGE}

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
