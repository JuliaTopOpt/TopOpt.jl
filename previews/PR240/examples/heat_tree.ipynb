# %% [markdown]
# # Heat conduction (conductivity tree) example

# %% [markdown]
# ## Commented Program
#
# This example minimizes the thermal compliance of a heat-conduction problem:
# distributed heat flux enters the top edge, the bottom edge is held at
# `T = 0`, and the sides are insulated. The optimal layout is the classic
# branching "conductivity tree" (Bendsøe & Sigmund, *Topology Optimization*,
# §1.3).

# %%
using TopOpt

# %% [markdown]
# ### Define the problem
# `HeatTree` sets up the standard benchmark: flux `q` on the top boundary,
# `T = 0` on the bottom, free left/right.

# %%
nels = (80, 40)
k = 1.0
q = 1.0
problem = HeatTree(Val{:Linear}, nels, (1.0, 1.0), k; q=q)
# Out:
# TopOpt heat conduction problem

# %% [markdown]
# ### Parameter settings

# %%
V = 0.3      # volume fraction
xmin = 1e-3  # minimum density
rmin = 2.0

x0 = fill(V, TopOpt.getncells(problem))
solver = FEASolver(DirectSolver, problem; xmin=xmin, penalty=PowerPenalty(3.0))
comp = ThermalCompliance(solver)
filter = DensityFilter(solver; rmin=rmin)
obj = x -> comp(filter(PseudoDensities(x)))
# Out:
# #2 (generic function with 1 method)

# %% [markdown]
# Define volume constraint

# %%
volfrac = Volume(solver)
constr = x -> volfrac(filter(PseudoDensities(x))) - V
model = Model(obj)
addvar!(model, zeros(length(x0)), ones(length(x0)))
add_ineq_constraint!(model, constr)
alg = MMA87()
# Out:
# MMA87{GradientDescent{LineSearches.InitialPrevious{Float64}, LineSearches.HagerZhang{Float64, Base.RefValue{Bool}}, Nothing, Returns{Nothing}}}(GradientDescent{LineSearches.InitialPrevious{Float64}, LineSearches.HagerZhang{Float64, Base.RefValue{Bool}}, Nothing, Returns{Nothing}}(LineSearches.InitialPrevious{Float64}(1.0, 0.0, Inf), LineSearches.HagerZhang{Float64, Base.RefValue{Bool}}(0.1, 0.9, Inf, 5.0, 1.0e-6, 0.66, 50, 0.1, 0, Base.RefValue{Bool}(false), nothing, false), nothing, Returns{Nothing}(nothing), Flat()))

# %% [markdown]
# ### Optimize

# %%
options = MMAOptions(; tol=Tolerance(; kkt=1e-4), maxiter=200)
res = optimize(model, alg, x0; options)

@show obj(res.minimizer)
@show constr(res.minimizer)
# Out:
# [ Info:   iter       obj      Δobj  violation  kkt_residual
# [ Info:      0   1.1e+05       Inf   1.7e-16   4.0e+02
# [ Info:      1   1.1e+05   5.5e-03   0.0e+00   5.5e-03
# [ Info:      2   1.1e+05   1.4e-08   0.0e+00   5.5e-03
# [ Info:      3   1.1e+05   1.4e-08   0.0e+00   5.5e-03
# [ Info:      4   1.1e+05   1.9e-03   0.0e+00   3.7e-03
# [ Info:      5   1.1e+05   2.9e-04   0.0e+00   4.0e-03
# [ Info:      6   1.1e+05   2.4e-04   0.0e+00   3.7e-03
# [ Info:      7   1.1e+05   1.6e-05   0.0e+00   3.7e-03
# [ Info:      8   1.1e+05   4.8e-04   0.0e+00   3.3e-03
# [ Info:      9   1.1e+05   8.9e-04   0.0e+00   2.4e-03
# [ Info:     10   1.1e+05   1.4e-04   0.0e+00   2.5e-03
# [ Info:     11   1.1e+05   1.4e-04   0.0e+00   2.4e-03
# [ Info:     90   1.6e+04   2.6e-01   0.0e+00   1.1e+00
# [ Info:     91   1.6e+04   3.3e-01   0.0e+00   1.5e+00
# [ Info:     92   1.6e+04   3.0e-01   0.0e+00   2.4e+00
# [ Info:     93   1.6e+04   1.4e-01   0.0e+00   3.7e+00
# [ Info:     94   1.6e+04   1.6e-02   0.0e+00   6.0e+00
# [ Info:     95   1.6e+04   9.8e-01   0.0e+00   3.8e+00
# [ Info:     96   1.6e+04   1.3e+00   0.0e+00   2.7e+00
# [ Info:     97   1.6e+04   9.6e-01   0.0e+00   2.7e+00
# [ Info:     98   1.6e+04   8.1e-01   0.0e+00   2.8e+00
# [ Info:     99   1.6e+04   9.5e-01   0.0e+00   2.9e+00
# [ Info:    100   1.6e+04   8.2e-01   0.0e+00   1.4e+00
# [ Info:    101   1.6e+04   4.8e-01   0.0e+00   1.5e+00
# [ Info:    102   1.6e+04   4.3e-01   0.0e+00   1.5e+00
# [ Info:    103   1.6e+04   4.5e-01   0.0e+00   1.5e+00
# [ Info:    104   1.6e+04   3.8e-01   0.0e+00   1.4e+00
# [ Info:    105   1.6e+04   4.0e-01   0.0e+00   1.5e+00
# [ Info:    106   1.6e+04   4.6e-01   0.0e+00   1.8e+00
# [ Info:    107   1.6e+04   5.3e-01   0.0e+00   2.0e+00
# [ Info:    108   1.6e+04   4.8e-01   0.0e+00   2.2e+00
# [ Info:    109   1.6e+04   3.8e-01   0.0e+00   2.2e+00
# [ Info:    110   1.6e+04   3.4e-01   0.0e+00   2.3e+00
# [ Info:    111   1.6e+04   3.4e-01   0.0e+00   3.0e+00
# [ Info:    112   1.6e+04   6.2e-01   0.0e+00   2.6e+00
# [ Info:    113   1.6e+04   5.9e-01   0.0e+00   2.7e+00
# [ Info:    114   1.6e+04   4.3e-01   0.0e+00   1.4e+00
# [ Info:    115   1.6e+04   3.2e-01   0.0e+00   9.0e-01
# [ Info:    116   1.6e+04   2.0e-01   0.0e+00   8.8e-01
# [ Info:    117   1.6e+04   1.8e-01   0.0e+00   8.7e-01
# [ Info:    118   1.6e+04   1.9e-01   0.0e+00   8.8e-01
# [ Info:    119   1.6e+04   2.0e-01   0.0e+00   9.0e-01
# [ Info:    120   1.6e+04   2.1e-01   0.0e+00   9.3e-01
# [ Info:    121   1.6e+04   2.2e-01   0.0e+00   1.0e+00
# [ Info:    122   1.6e+04   1.8e-01   0.0e+00   1.0e+00
# [ Info:    123   1.6e+04   1.5e-01   0.0e+00   9.5e-01
# [ Info:    124   1.6e+04   1.7e-01   0.0e+00   9.5e-01
# [ Info:    125   1.6e+04   1.9e-01   0.0e+00   8.5e-01
# [ Info:    126   1.6e+04   2.2e-01   0.0e+00   9.1e-01
# [ Info:    127   1.6e+04   2.6e-01   0.0e+00   7.2e-01
# [ Info:    128   1.6e+04   2.8e-01   0.0e+00   1.2e+00
# [ Info:    129   1.6e+04   1.8e-01   0.0e+00   2.2e+00
# [ Info:    130   1.6e+04   2.2e-01   0.0e+00   5.0e+00
# [ Info:    131   1.6e+04   2.4e-01   0.0e+00   4.8e+00
# [ Info:    132   1.6e+04   2.4e-01   0.0e+00   7.7e+00
# [ Info:    133   1.6e+04   1.8e+00   0.0e+00   3.1e+00
# [ Info:    134   1.6e+04   1.2e+00   0.0e+00   1.7e+00
# [ Info:    135   1.6e+04   8.1e-01   0.0e+00   1.6e+00
# [ Info:    136   1.6e+04   7.9e-01   0.0e+00   1.6e+00
# [ Info:    137   1.6e+04   4.4e-01   0.0e+00   1.3e+00
# [ Info:    138   1.6e+04   3.0e-01   0.0e+00   1.4e+00
# [ Info:    139   1.6e+04   1.7e-01   0.0e+00   1.3e+00
# [ Info:    140   1.6e+04   1.6e-01   0.0e+00   6.9e-01
# [ Info:    141   1.6e+04   1.3e-01   0.0e+00   7.6e-01
# [ Info:    142   1.6e+04   1.3e-01   0.0e+00   8.4e-01
# [ Info:    143   1.6e+04   1.4e-01   0.0e+00   8.6e-01
# [ Info:    144   1.6e+04   1.5e-01   0.0e+00   9.2e-01
# [ Info:    145   1.6e+04   1.6e-01   0.0e+00   9.9e-01
# [ Info:    146   1.6e+04   1.9e-01   0.0e+00   1.0e+00
# [ Info:    147   1.6e+04   2.2e-01   0.0e+00   8.5e-01
# [ Info:    148   1.6e+04   1.7e-01   0.0e+00   6.6e-01
# [ Info:    149   1.6e+04   1.6e-01   0.0e+00   7.9e-01
# [ Info:    150   1.6e+04   1.8e-01   0.0e+00   1.0e+00
# [ Info:    151   1.6e+04   2.3e-01   0.0e+00   1.1e+00
# [ Info:    152   1.6e+04   3.2e-01   0.0e+00   1.5e+00
# [ Info:    153   1.6e+04   4.7e-01   0.0e+00   1.5e+00
# [ Info:    154   1.6e+04   4.7e-01   0.0e+00   2.1e+00
# [ Info:    155   1.6e+04   2.4e-01   0.0e+00   2.6e+00
# [ Info:    156   1.6e+04   4.2e-01   0.0e+00   5.6e+00
# [ Info:    157   1.6e+04   3.4e+00   0.0e+00   1.5e+01
# [ Info:    158   1.6e+04   1.4e+00   0.0e+00   1.3e+01
# [ Info:    159   1.6e+04   1.1e+00   0.0e+00   1.1e+01
# [ Info:    160   1.6e+04   3.0e+00   0.0e+00   5.2e+00
# [ Info:    161   1.6e+04   1.6e+00   0.0e+00   1.9e+00
# [ Info:    162   1.6e+04   2.2e-01   0.0e+00   1.7e+00
# [ Info:    163   1.6e+04   3.8e-02   0.0e+00   1.6e+00
# [ Info:    164   1.6e+04   3.3e-02   0.0e+00   1.5e+00
# [ Info:    165   1.6e+04   3.3e-02   0.0e+00   1.4e+00
# [ Info:    166   1.6e+04   3.5e-02   0.0e+00   1.4e+00
# [ Info:    167   1.6e+04   3.9e-02   0.0e+00   1.4e+00
# [ Info:    168   1.6e+04   4.6e-02   0.0e+00   1.4e+00
# [ Info:    169   1.6e+04   5.3e-02   0.0e+00   1.4e+00
# [ Info:    170   1.6e+04   6.1e-02   0.0e+00   1.4e+00
# [ Info:    171   1.6e+04   7.0e-02   0.0e+00   1.4e+00
# [ Info:    172   1.6e+04   8.0e-02   0.0e+00   1.4e+00
# [ Info:    173   1.6e+04   9.3e-02   0.0e+00   1.4e+00
# [ Info:    174   1.6e+04   1.0e-01   0.0e+00   9.9e-01
# [ Info:    175   1.6e+04   9.2e-02   0.0e+00   8.4e-01
# [ Info:    176   1.6e+04   8.8e-02   0.0e+00   6.5e-01
# [ Info:    177   1.6e+04   3.7e-02   0.0e+00   3.1e-01
# [ Info:    178   1.6e+04   2.3e-02   0.0e+00   2.5e-01
# [ Info:    179   1.6e+04   1.6e-02   0.0e+00   3.5e-01
# [ Info:    180   1.6e+04   1.5e-02   0.0e+00   2.2e-01
# [ Info:    181   1.6e+04   1.4e-02   0.0e+00   3.6e-01
# [ Info:    182   1.6e+04   1.4e-02   0.0e+00   2.1e-01
# [ Info:    183   1.6e+04   1.3e-02   0.0e+00   3.8e-01
# [ Info:    184   1.6e+04   1.3e-02   0.0e+00   2.0e-01
# [ Info:    185   1.6e+04   1.3e-02   0.0e+00   3.8e-01
# [ Info:    186   1.6e+04   1.3e-02   0.0e+00   2.0e-01
# [ Info:    187   1.6e+04   1.3e-02   0.0e+00   3.5e-01
# [ Info:    188   1.6e+04   1.3e-02   0.0e+00   2.2e-01
# [ Info:    189   1.6e+04   1.3e-02   0.0e+00   3.0e-01
# [ Info:    190   1.6e+04   1.3e-02   0.0e+00   2.2e-01
# [ Info:    191   1.6e+04   1.4e-02   0.0e+00   2.4e-01
# [ Info:    192   1.6e+04   1.5e-02   0.0e+00   1.8e-01
# [ Info:    193   1.6e+04   1.5e-02   0.0e+00   2.0e-01
# [ Info:    194   1.6e+04   1.4e-02   0.0e+00   1.7e-01
# [ Info:    195   1.6e+04   1.5e-02   0.0e+00   2.1e-01
# [ Info:    196   1.6e+04   1.5e-02   0.0e+00   1.9e-01
# [ Info:    197   1.6e+04   1.4e-02   0.0e+00   2.5e-01
# [ Info:    198   1.6e+04   1.4e-02   0.0e+00   2.4e-01
# [ Info:    199   1.6e+04   1.4e-02   0.0e+00   3.3e-01
# [ Info:    200   1.6e+04   1.3e-02   0.0e+00   3.2e-01
# obj(res.minimizer) = 16143.422330148447
# constr(res.minimizer) = -6.767856725042876e-8
# -6.767856725042876e-8

# %% [markdown]
# ### (Optional) Visualize the result using Makie.jl
# Need to run `using Pkg; Pkg.add("Makie")` first and either `Pkg.add("CairoMakie")` or `Pkg.add("GLMakie")`

# %%
using Makie
using CairoMakie

# %% [markdown]
# alternatively, `using GLMakie`

# %%
fig = visualize(problem; topology=res.minimizer)
Makie.display(fig)
# Out:
# Figure()
# CairoMakie.Screen{IMAGE}

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
