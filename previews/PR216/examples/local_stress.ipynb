# %% [markdown]
# using Revise

# %%
using TopOpt, LinearAlgebra, StatsFuns
using StatsFuns: logsumexp

E = 1.0 # Young’s modulus
v = 0.3 # Poisson’s ratio
f = 1.0 # downward force
rmin = 3.0
# Out:
# 3.0

# %% [markdown]
# ### Define the problem

# %%
problem = PointLoadCantilever(Val{:Linear}, (160, 40), (1.0, 1.0), E, v, f)
# Out:
# TopOpt point load cantilever beam problem

# %% [markdown]
# ### Parameter settings

# %%
V = 0.5 # volume fraction
xmin = 0.0001 # minimum density
steps = 40 # maximum number of penalty steps, delta_p0 = 0.1
# Out:
# 40

# %% [markdown]
# ### Continuation SIMP

# %%
x0 = fill(0.5, 160 * 40) # initial design
N = length(x0)
penalty = TopOpt.PowerPenalty(1.0)
solver = FEASolver(DirectSolver, problem; xmin=xmin, penalty=penalty)
stress = TopOpt.von_mises_stress_function(solver)
filter = DensityFilter(solver; rmin=rmin)
volfrac = TopOpt.Volume(solver)

obj = x -> volfrac(filter(PseudoDensities(x))) - V
thr = 150 # stress threshold
constr = x -> begin
    s = stress(filter(PseudoDensities(x)))
    return (s .- thr) / length(s)
end
alg = PercivalAlg()
options = PercivalOptions()
model = Model(obj)
addvar!(model, zeros(N), ones(N))
add_ineq_constraint!(model, constr)

x = copy(x0)
for p in [1.0, 2.0, 3.0]
    TopOpt.setpenalty!(solver, p)
    global r = optimize(model, alg, x; options)
    global x = r.minimizer
end

maximum(stress(filter(PseudoDensities(x0))))
maximum(stress(filter(PseudoDensities(x))))
# Out:
# [ Info:   iter        fx    normgp    normcx         μ     normy    sumc     inner_status        iter_type
# [ Info:      0  -3.3e-16   8.0e+01   1.9e+00   1.0e+01   8.0e+01       5
# [ Info:      1   3.6e-15   8.0e+01   1.9e+00   1.0e+02   8.0e+01       9      first_order         update_μ
# [ Info:      2  -6.6e-06   8.0e+01   8.0e-01   1.0e+03   8.0e+01      22      first_order         update_μ
# [ Info:      3  -4.9e-01   1.7e+00   8.1e-02   1.0e+03   1.7e+00     563         max_eval         update_y
# [ Info:      4  -4.9e-01   1.7e+00   8.1e-02   1.0e+04   1.7e+00     567         max_eval         update_μ
# [ Info:      5  -4.9e-01   7.9e+01   8.1e-02   1.0e+04   8.2e+02     571         max_eval         update_y
# [ Info:      6  -4.9e-01   7.9e+01   8.1e-02   1.0e+05   8.2e+02     575         max_eval         update_μ
# [ Info:      7  -4.9e-01   7.9e+01   8.1e-02   1.0e+05   9.0e+03     579         max_eval         update_y
# [ Info:      8  -4.9e-01   7.9e+01   8.1e-02   1.0e+06   9.0e+03     583         max_eval         update_μ
# [ Info:      9  -4.9e-01   7.9e+01   8.1e-02   1.0e+06   9.0e+04     587         max_eval         update_y
# [ Info:     10  -4.9e-01   7.9e+01   8.1e-02   1.0e+07   9.0e+04     591         max_eval         update_μ
# [ Info:     11  -4.9e-01   7.9e+01   8.1e-02   1.0e+07   9.0e+05     595         max_eval         update_y
# [ Info:     12  -4.9e-01   7.9e+01   8.1e-02   1.0e+08   9.0e+05     599         max_eval         update_μ
# [ Info:     13  -4.9e-01   7.9e+01   8.1e-02   1.0e+08   9.0e+06     603         max_eval         update_y
# [ Info:     14  -4.9e-01   7.9e+01   8.1e-02   1.0e+09   9.0e+06     607         max_eval         update_μ
# [ Info:     15  -4.9e-01   7.9e+01   8.1e-02   1.0e+09   9.0e+07     611         max_eval         update_y
# [ Info:     16  -4.9e-01   7.9e+01   8.1e-02   1.0e+10   9.0e+07     615         max_eval         update_μ
# [ Info:     17  -4.9e-01   7.9e+01   8.1e-02   1.0e+10   9.0e+08     619         max_eval         update_y
# [ Info:     18  -4.9e-01   7.9e+01   8.1e-02   1.0e+11   9.0e+08     623         max_eval         update_μ
# [ Info:     19  -4.9e-01   7.9e+01   8.1e-02   1.0e+12   9.0e+08     627         max_eval         update_μ
# [ Info:     20  -4.9e-01   7.9e+01   8.1e-02   1.0e+13   9.0e+08     631         max_eval         update_μ
# [ Info:     21  -4.9e-01   7.9e+01   8.1e-02   1.0e+14   9.0e+08     635         max_eval         update_μ
# [ Info:     22  -4.9e-01   7.9e+01   8.1e-02   1.0e+15   9.0e+08     639         max_eval         update_μ
# [ Info:     23  -4.9e-01   7.9e+01   8.1e-02   1.0e+16   9.0e+08     643         max_eval         update_μ
# [ Info:     24  -5.0e-01   7.9e+01   8.1e-02   1.0e+17   9.0e+08     647         max_eval         update_μ
# [ Info:   iter        fx    normgp    normcx         μ     normy    sumc     inner_status        iter_type
# [ Info:      0  -4.9e-01   8.0e+01   6.2e+00   1.0e+01   8.0e+01       5
# [ Info:      1  -4.9e-01   8.0e+01   6.2e+00   1.0e+02   8.0e+01       9      first_order         update_μ
# [ Info:      2  -4.1e-01   8.0e+01   8.0e-01   1.0e+03   8.0e+01      40      first_order         update_μ
# [ Info:      3  -4.0e-01   1.8e-02   8.0e-02   1.0e+03   1.1e-02      74      first_order         update_y
# [ Info:      4  -4.2e-01   2.3e-01   3.7e-04   1.0e+03   3.7e-01     590         max_eval         update_y
# [ Info:      5  -4.2e-01   2.3e-01   3.7e-04   1.0e+04   3.7e-01     594         max_eval         update_μ
# [ Info:      6  -4.2e-01   2.5e+00   3.7e-04   1.0e+04   4.1e+00     598         max_eval         update_y
# [ Info:      7  -4.2e-01   2.5e+00   3.7e-04   1.0e+05   4.1e+00     602         max_eval         update_μ
# [ Info:      8  -4.2e-01   2.4e+01   3.7e-04   1.0e+05   4.1e+01     606         max_eval         update_y
# [ Info:      9  -4.2e-01   2.4e+01   3.7e-04   1.0e+06   4.1e+01     610         max_eval         update_μ
# [ Info:     10  -4.2e-01   2.3e+02   3.7e-04   1.0e+06   4.1e+02     614         max_eval         update_y
# [ Info:     11  -4.2e-01   2.3e+02   3.7e-04   1.0e+07   4.1e+02     618         max_eval         update_μ
# [ Info:     12  -4.2e-01   2.3e+03   3.7e-04   1.0e+07   4.1e+03     622         max_eval         update_y
# [ Info:     13  -4.2e-01   2.3e+03   3.7e-04   1.0e+08   4.1e+03     626         max_eval         update_μ
# [ Info:     14  -4.2e-01   2.3e+04   3.7e-04   1.0e+08   4.1e+04     630         max_eval         update_y
# [ Info:     15  -4.2e-01   2.3e+04   3.7e-04   1.0e+09   4.1e+04     634         max_eval         update_μ
# [ Info:     16  -4.2e-01   2.3e+05   3.7e-04   1.0e+09   4.1e+05     638         max_eval         update_y
# [ Info:     17  -4.2e-01   2.3e+05   3.7e-04   1.0e+10   4.1e+05     642         max_eval         update_μ
# [ Info:     18  -4.2e-01   2.3e+06   3.7e-04   1.0e+10   4.1e+06     646         max_eval         update_y
# [ Info:     19  -4.2e-01   2.3e+06   3.7e-04   1.0e+11   4.1e+06     650         max_eval         update_μ
# [ Info:     20  -4.2e-01   2.3e+07   3.7e-04   1.0e+11   4.1e+07     654         max_eval         update_y
# [ Info:     21  -4.2e-01   2.3e+07   3.7e-04   1.0e+12   4.1e+07     658         max_eval         update_μ
# [ Info:     22  -4.2e-01   2.3e+08   3.7e-04   1.0e+12   4.1e+08     662         max_eval         update_y
# [ Info:     23  -4.2e-01   2.3e+08   3.7e-04   1.0e+13   4.1e+08     666         max_eval         update_μ
# [ Info:     24  -4.2e-01   2.3e+09   3.7e-04   1.0e+13   4.1e+09     670         max_eval         update_y
# [ Info:     25  -4.2e-01   2.3e+09   3.7e-04   1.0e+14   4.1e+09     674         max_eval         update_μ
# [ Info:     26  -4.2e-01   2.3e+10   3.7e-04   1.0e+14   4.1e+10     678         max_eval         update_y
# [ Info:     27  -4.2e-01   2.3e+10   3.7e-04   1.0e+15   4.1e+10     682         max_eval         update_μ
# [ Info:     28  -4.2e-01   2.3e+11   3.7e-04   1.0e+15   4.1e+11     686         max_eval         update_y
# [ Info:     29  -4.2e-01   2.3e+11   3.7e-04   1.0e+16   4.1e+11     690         max_eval         update_μ
# [ Info:     30  -4.2e-01   2.3e+12   3.7e-04   1.0e+16   4.1e+12     694         max_eval         update_y
# [ Info:     31  -4.2e-01   2.3e+12   3.7e-04   1.0e+17   4.1e+12     698         max_eval         update_μ
# [ Info:   iter        fx    normgp    normcx         μ     normy    sumc     inner_status        iter_type
# [ Info:      0  -4.2e-01   8.0e+01   3.5e+00   1.0e+01   8.0e+01       5
# [ Info:      1  -4.2e-01   8.0e+01   3.5e+00   1.0e+02   8.0e+01       9      first_order         update_μ
# [ Info:      2  -3.4e-01   8.0e+01   8.0e-01   1.0e+03   8.0e+01      28      first_order         update_μ
# [ Info:      3  -3.4e-01   5.4e-02   8.0e-02   1.0e+03   1.1e-01      83      first_order         update_y
# [ Info:      4  -3.5e-01   5.2e-02   4.5e-04   1.0e+03   4.4e-01     600         max_eval         update_y
# [ Info:      5  -3.5e-01   5.2e-02   4.5e-04   1.0e+04   4.4e-01     604         max_eval         update_μ
# [ Info:      6  -3.5e-01   1.1e+00   4.5e-04   1.0e+04   5.0e+00     608         max_eval         update_y
# [ Info:      7  -3.5e-01   1.1e+00   4.5e-04   1.0e+05   5.0e+00     612         max_eval         update_μ
# [ Info:      8  -3.5e-01   1.2e+01   4.5e-04   1.0e+05   5.0e+01     616         max_eval         update_y
# [ Info:      9  -3.5e-01   1.2e+01   4.5e-04   1.0e+06   5.0e+01     620         max_eval         update_μ
# [ Info:     10  -3.5e-01   1.1e+02   4.5e-04   1.0e+06   5.0e+02     624         max_eval         update_y
# [ Info:     11  -3.5e-01   1.1e+02   4.5e-04   1.0e+07   5.0e+02     628         max_eval         update_μ
# [ Info:     12  -3.5e-01   1.1e+03   4.5e-04   1.0e+07   5.0e+03     632         max_eval         update_y
# [ Info:     13  -3.5e-01   1.1e+03   4.5e-04   1.0e+08   5.0e+03     636         max_eval         update_μ
# [ Info:     14  -3.5e-01   1.1e+04   4.5e-04   1.0e+08   5.0e+04     640         max_eval         update_y
# [ Info:     15  -3.5e-01   1.1e+04   4.5e-04   1.0e+09   5.0e+04     644         max_eval         update_μ
# [ Info:     16  -3.5e-01   1.1e+05   4.5e-04   1.0e+09   5.0e+05     648         max_eval         update_y
# [ Info:     17  -3.5e-01   1.1e+05   4.5e-04   1.0e+10   5.0e+05     652         max_eval         update_μ
# [ Info:     18  -3.5e-01   1.1e+06   4.5e-04   1.0e+10   5.0e+06     656         max_eval         update_y
# [ Info:     19  -3.5e-01   1.1e+06   4.5e-04   1.0e+11   5.0e+06     660         max_eval         update_μ
# [ Info:     20  -3.5e-01   1.1e+07   4.5e-04   1.0e+11   5.0e+07     664         max_eval         update_y
# [ Info:     21  -3.5e-01   1.1e+07   4.5e-04   1.0e+12   5.0e+07     668         max_eval         update_μ
# [ Info:     22  -3.5e-01   1.1e+08   4.5e-04   1.0e+12   5.0e+08     672         max_eval         update_y
# [ Info:     23  -3.5e-01   1.1e+08   4.5e-04   1.0e+13   5.0e+08     676         max_eval         update_μ
# [ Info:     24  -3.5e-01   1.1e+09   4.5e-04   1.0e+13   5.0e+09     680         max_eval         update_y
# [ Info:     25  -3.5e-01   1.1e+09   4.5e-04   1.0e+14   5.0e+09     684         max_eval         update_μ
# [ Info:     26  -3.5e-01   1.1e+10   4.5e-04   1.0e+14   5.0e+10     688         max_eval         update_y
# [ Info:     27  -3.5e-01   1.1e+10   4.5e-04   1.0e+15   5.0e+10     692         max_eval         update_μ
# [ Info:     28  -3.5e-01   1.1e+11   4.5e-04   1.0e+15   5.0e+11     696         max_eval         update_y
# [ Info:     29  -3.5e-01   1.1e+11   4.5e-04   1.0e+16   5.0e+11     700         max_eval         update_μ
# [ Info:     30  -3.5e-01   1.1e+12   4.5e-04   1.0e+16   5.0e+12     704         max_eval         update_y
# [ Info:     31  -3.5e-01   1.1e+12   4.5e-04   1.0e+17   5.0e+12     708         max_eval         update_μ
# 151.94796870388114

# %% [markdown]
# ### (Optional) Visualize the result using Makie.jl
# Need to run `using Pkg; Pkg.add("Makie")` first and either `Pkg.add("CairoMakie")` or `Pkg.add("GLMakie")`

# %%
using Makie
using CairoMakie

# %% [markdown]
# alternatively, `using GLMakie`

# %%
fig = visualize(
    problem;
    topology=r.minimizer,
    default_exagg_scale=0.07,
    scale_range=10.0,
    vector_arrowsize=0.5,
)
Makie.display(fig)
# Out:
# Figure()
# CairoMakie.Screen{IMAGE}

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
